# %%
# Simple Python Program in Google Colab

# Print a message
print("Hello, GitHub!")

# Perform basic math operations
x = 10
y = 5
sum_result = x + y
diff_result = x - y

# Display results
print("Sum:", sum_result)
print("Difference:", diff_result)

# Save results to a text file
with open("output.txt", "w") as file:
    file.write(f"Sum: {sum_result}\n")
    file.write(f"Difference: {diff_result}\n")

print("Results saved to output.txt")
# Out:
# Hello, GitHub!
# Sum: 15
# Difference: 5
# Results saved to output.txt

# %%
# !rm -rf colab-notebook
# !git clone https://github.com/Amnaahmed798/colab-notebook.git
# Out:
# Cloning into 'colab-notebook'...
# ...

# %%
# !git clone https://github.com/Amnaahmed798/colab-notebook.git
# Out:
# fatal: destination path 'colab-notebook' already exists and is not an empty directory.

# %%
# !rm -rf colab-notebook
# !git clone https://github.com/Amnaahmed798/colab-notebook.git
# Out:
# Cloning into 'colab-notebook'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd colab-notebook
# Out:
# /content/colab-notebook

# %%
# !cp /content/my_colab_notebook.ipynb /content/colab-notebook/
# Out:
# cp: cannot stat '/content/my_colab_notebook.ipynb': No such file or directory

# %%
# !ls /content/
# Out:
# colab-notebook	sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# my_colab_notebook.ipynb  sample1.ipynb	Untitled
